# %%
import os
import shutil
import nibabel as nib
import cv2
import numpy as np
import pathlib
import re
import json
from collections import defaultdict
import random

def natural_sort_key(s, _nsre=re.compile('([0-9]+)')):
    return [int(text) if text.isdigit() else text.lower()
            for text in re.split(_nsre, s)]

# Input directories
path = "ArabidopsisDataset"
read_path = pathlib.Path(path).glob('*/*/*/*.png')
image_paths = sorted([str(path) for path in read_path], key=natural_sort_key)

# Output directories
outpath = "nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/imagesTr"
labels_outpath = "nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/labelsTr"

os.makedirs(outpath, exist_ok=True)
os.makedirs(labels_outpath, exist_ok=True)

# Group images by folder
folder_images = defaultdict(list)
for path in image_paths:
    # Get the folder path - using os.path for better compatibility
    folder_path = os.path.dirname(path)
    folder_images[folder_path].append(path)

# Create a mapping dictionary that includes the folder info
folder_image_map = defaultdict(list)

# Counter for image naming
counter = 1
image_id = ""

# Process all images grouped by folder
for folder, images in folder_images.items():
    folder_id = "Manual_Annotation_" + folder.replace("/", "_").replace(" ", "_")  # Create a safe folder ID
    
    print(f'Processing {folder}, image ID: {image_id}')
        
    # Process each image in the folder
    for path in images:
        # Create image ID
        image_id = f'image_{counter}'
        
        # Copy the image to the output directory
        shutil.copy(path, os.path.join(outpath, f'{image_id}_0000.png'))
        
        # Load the mask
        mask_path = path.replace('.png', '.nii.gz')
        mask = nib.load(mask_path).get_fdata().T
        
        if mask.shape[0] == 1:
            mask = mask[0]
        
        image = cv2.imread(path, 0)
        # Image shape and mask shape should be the same
        if image.shape[0] != mask.shape[0]:
            continue

        # Save the mask
        cv2.imwrite(os.path.join(labels_outpath, f'{image_id}.png'), mask.astype('uint8'))
        
        folder_image_map[folder_id].append(image_id)
        
        # Update the counter
        counter += 1

with open('nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/folder_image_map.json', '+w') as f:
    json.dump(folder_image_map, f, indent=4)
# Out:
# Processing ArabidopsisDataset/Etiolation/MultipleVids/Primeras listo, image ID:
# Processing ArabidopsisDataset/Etiolation/MultipleVids/Varios, image ID: image_4
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-07-29_14-47/1 listo, image ID: image_12
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-07-29_14-47/2 listo, image ID: image_16
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-07-29_14-47/3 listo, image ID: image_20
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-11-06_15-18/1, image ID: image_24
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-11-06_15-18/2, image ID: image_29
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-11-06_15-18/3, image ID: image_34
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-11-06_15-18/4, image ID: image_39
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-06-11_14-10/1 listo, image ID: image_44
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-06-11_14-10/2 listo, image ID: image_48
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-06-11_14-10/3 listo, image ID: image_52
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-06-11_14-10/4 listo, image ID: image_56
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-07-29_14-54/1 listo, image ID: image_60
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-07-29_14-54/2 listo, image ID: image_64
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-07-29_14-54/3 listo, image ID: image_68
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-07-29_14-54/4 listo, image ID: image_72
# Processing ArabidopsisDataset/Germination/MultipleVids/AnnotatedSeeds, image ID: image_76
# Processing ArabidopsisDataset/Germination/MultipleVids/Varios, image ID: image_140
# Processing ArabidopsisDataset/Germination/rpi8_2024-07-02_14-41/1, image ID: image_162
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-02_14-40/1, image ID: image_164
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-02_14-40/2, image ID: image_166
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-02_14-40/3, image ID: image_168
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-02_14-40/4, image ID: image_170
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-08_15-50/1, image ID: image_172
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-08_15-50/2, image ID: image_174
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-08_15-50/3, image ID: image_176
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-08_15-50/4, image ID: image_178
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-16_10-09/1, image ID: image_180
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-16_10-09/2, image ID: image_182
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-16_10-09/3, image ID: image_183
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-16_10-09/4, image ID: image_184
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-22_13-29/1, image ID: image_185
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-22_13-29/2, image ID: image_186
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-22_13-29/3, image ID: image_187
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-22_13-29/4, image ID: image_188
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-16_10-10/1, image ID: image_189
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-16_10-10/2, image ID: image_190
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-16_10-10/3, image ID: image_192
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-16_10-10/4, image ID: image_193
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-22_13-31/1, image ID: image_194
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-22_13-31/2, image ID: image_196
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-22_13-31/3, image ID: image_198
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-22_13-31/4, image ID: image_201
# Processing ArabidopsisDataset/Germination/rpi101_2024-09-06_16-14/1, image ID: image_203
# Processing ArabidopsisDataset/Germination/rpi101_2024-09-06_16-14/2, image ID: image_208
# Processing ArabidopsisDataset/Germination/rpi101_2024-09-06_16-14/3, image ID: image_213
# Processing ArabidopsisDataset/Germination/rpi101_2024-09-06_16-14/4, image ID: image_218
# Processing ArabidopsisDataset/Germination/rpi101_2025-04-25_14-50/1, image ID: image_223
# Processing ArabidopsisDataset/Germination/rpi101_2025-04-25_14-50/2, image ID: image_227
# Processing ArabidopsisDataset/Germination/rpi101_2025-04-25_14-50/3, image ID: image_231
# Processing ArabidopsisDataset/Germination/rpi101_2025-04-25_14-50/4, image ID: image_235
# Processing ArabidopsisDataset/ManyRoots/rpi101_2024-11-25_14-48/1, image ID: image_239
# Processing ArabidopsisDataset/ManyRoots/rpi101_2024-11-25_14-48/2, image ID: image_246
# Processing ArabidopsisDataset/ManyRoots/rpi101_2024-11-25_14-48/3, image ID: image_253
# Processing ArabidopsisDataset/ManyRoots/rpi101_2024-11-25_14-48/4, image ID: image_260
# Processing ArabidopsisDataset/ManyRoots/rpi101_2025-04-16_17-10/1, image ID: image_267
# Processing ArabidopsisDataset/ManyRoots/rpi101_2025-04-16_17-10/2, image ID: image_273
# Processing ArabidopsisDataset/ManyRoots/rpi101_2025-04-16_17-10/3, image ID: image_279
# Processing ArabidopsisDataset/ManyRoots/rpi101_2025-04-16_17-10/4, image ID: image_285
# Processing ArabidopsisDataset/ManyRoots/rpi103_2024-11-25_14-49/1, image ID: image_291
# Processing ArabidopsisDataset/ManyRoots/rpi103_2024-11-25_14-49/2, image ID: image_298
# Processing ArabidopsisDataset/ManyRoots/rpi103_2024-11-25_14-49/3, image ID: image_305
# Processing ArabidopsisDataset/ManyRoots/rpi103_2024-11-25_14-49/4, image ID: image_312
# Processing ArabidopsisDataset/ManyRoots/rpi103_2025-04-16_17-11/1, image ID: image_319
# Processing ArabidopsisDataset/ManyRoots/rpi103_2025-04-16_17-11/2, image ID: image_325
# Processing ArabidopsisDataset/ManyRoots/rpi103_2025-04-16_17-11/3, image ID: image_331
# Processing ArabidopsisDataset/ManyRoots/rpi103_2025-04-16_17-11/4, image ID: image_337
# Processing ArabidopsisDataset/Roots/MultipleVids/rotas, image ID: image_343
# Processing ArabidopsisDataset/Roots/MultipleVids/rpi15_4, image ID: image_356
# Processing ArabidopsisDataset/Roots/rpi4_old/cam2, image ID: image_359
# Processing ArabidopsisDataset/Roots/rpi5_old/cam1, image ID: image_367
# Processing ArabidopsisDataset/Roots/rpi6/1, image ID: image_374
# Processing ArabidopsisDataset/Roots/rpi6/2, image ID: image_378
# Processing ArabidopsisDataset/Roots/rpi6/3, image ID: image_383
# Processing ArabidopsisDataset/Roots/rpi6/4, image ID: image_388
# Processing ArabidopsisDataset/Roots/rpi6_2019-12-09_16-12/1, image ID: image_393
# Processing ArabidopsisDataset/Roots/rpi6_2019-12-09_16-12/2, image ID: image_398
# Processing ArabidopsisDataset/Roots/rpi6_2019-12-09_16-12/3, image ID: image_403
# Processing ArabidopsisDataset/Roots/rpi6_2019-12-09_16-12/4, image ID: image_408
# Processing ArabidopsisDataset/Roots/rpi6_2020-01-08_17-25_cl/1, image ID: image_413
# Processing ArabidopsisDataset/Roots/rpi6_2020-01-08_17-25_cl/2, image ID: image_418
# Processing ArabidopsisDataset/Roots/rpi6_2020-01-08_17-25_cl/3, image ID: image_423
# Processing ArabidopsisDataset/Roots/rpi6_2020-01-08_17-25_cl/4, image ID: image_428
# Processing ArabidopsisDataset/Roots/rpi6_2020-03-12_17-01_ld/2, image ID: image_433
# Processing ArabidopsisDataset/Roots/rpi6_2020-03-12_17-01_ld/3, image ID: image_438
# Processing ArabidopsisDataset/Roots/rpi6_2020-03-12_17-01_ld/4, image ID: image_443
# Processing ArabidopsisDataset/Roots/rpi6_old/cam1, image ID: image_448
# Processing ArabidopsisDataset/Roots/rpi6_old/cam2, image ID: image_454
# Processing ArabidopsisDataset/Roots/rpi6_old/cam3, image ID: image_461
# Processing ArabidopsisDataset/Roots/rpi6_old/cam4, image ID: image_468
# Processing ArabidopsisDataset/Roots/rpi6_short_day_col0_ler/1, image ID: image_474
# Processing ArabidopsisDataset/Roots/rpi6_short_day_col0_ler/2, image ID: image_480
# Processing ArabidopsisDataset/Roots/rpi6_short_day_col0_ler/4, image ID: image_486
# Processing ArabidopsisDataset/Roots/rpi6_short_day_failed/1, image ID: image_492
# Processing ArabidopsisDataset/Roots/rpi6_short_day_failed/2, image ID: image_498
# Processing ArabidopsisDataset/Roots/rpi6_short_day_failed/3, image ID: image_504
# Processing ArabidopsisDataset/Roots/rpi6_short_day_failed/4, image ID: image_510
# Processing ArabidopsisDataset/Roots/rpi8_short_day_col0_ler/1, image ID: image_516
# Processing ArabidopsisDataset/Roots/rpi8_short_day_col0_ler/2, image ID: image_522
# Processing ArabidopsisDataset/Roots/rpi8_short_day_col0_ler/3, image ID: image_528
# Processing ArabidopsisDataset/Roots/rpi8_short_day_col0_ler/4, image ID: image_534
# Processing ArabidopsisDataset/Roots/rpi9_short_day_col0_ler/1, image ID: image_540
# Processing ArabidopsisDataset/Roots/rpi9_short_day_col0_ler/2, image ID: image_546
# Processing ArabidopsisDataset/Roots/rpi9_short_day_col0_ler/4, image ID: image_552
# Processing ArabidopsisDataset/Roots/rpi13_old/cam1, image ID: image_558
# Processing ArabidopsisDataset/Roots/rpi13_old/cam2, image ID: image_566
# Processing ArabidopsisDataset/Roots/rpi13_old/cam3, image ID: image_574
# Processing ArabidopsisDataset/Roots/rpi13_old/cam4, image ID: image_582
# Processing ArabidopsisDataset/Roots/rpi14_2019-12-09_16-13/1, image ID: image_589
# Processing ArabidopsisDataset/Roots/rpi14_2019-12-09_16-13/2, image ID: image_594
# Processing ArabidopsisDataset/Roots/rpi14_2019-12-09_16-13/3, image ID: image_599
# Processing ArabidopsisDataset/Roots/rpi14_2019-12-09_16-13/4, image ID: image_604
# Processing ArabidopsisDataset/Roots/rpi14_2020-01-08_17-25_cl/1, image ID: image_609
# Processing ArabidopsisDataset/Roots/rpi14_2020-01-08_17-25_cl/3, image ID: image_614
# Processing ArabidopsisDataset/Roots/rpi14_2020-01-08_17-25_cl/4, image ID: image_619
# Processing ArabidopsisDataset/Roots/rpi14_2020-03-12_17-00_ld/1, image ID: image_623
# Processing ArabidopsisDataset/Roots/rpi14_2020-03-12_17-00_ld/2, image ID: image_628
# Processing ArabidopsisDataset/Roots/rpi14_2020-03-12_17-00_ld/3, image ID: image_633
# Processing ArabidopsisDataset/Roots/rpi14_2020-03-12_17-00_ld/4, image ID: image_638
# Processing ArabidopsisDataset/Roots/rpi14_old/cam1, image ID: image_643
# Processing ArabidopsisDataset/Roots/rpi14_old/cam2, image ID: image_652
# Processing ArabidopsisDataset/Roots/rpi14_old/cam3, image ID: image_660
# Processing ArabidopsisDataset/Roots/rpi14_old/cam4, image ID: image_668
# Processing ArabidopsisDataset/Roots/rpi14_short_day_failed/1, image ID: image_677
# Processing ArabidopsisDataset/Roots/rpi14_short_day_failed/2, image ID: image_683
# Processing ArabidopsisDataset/Roots/rpi14_short_day_failed/3, image ID: image_689
# Processing ArabidopsisDataset/Roots/rpi14_short_day_failed/4, image ID: image_695
# Processing ArabidopsisDataset/Roots/rpi15_2019-12-09_16-14/1, image ID: image_701
# Processing ArabidopsisDataset/Roots/rpi15_2019-12-09_16-14/2, image ID: image_706
# Processing ArabidopsisDataset/Roots/rpi15_2019-12-09_16-14/3, image ID: image_711
# Processing ArabidopsisDataset/Roots/rpi15_2020-01-08_17-24_cl/1, image ID: image_716
# Processing ArabidopsisDataset/Roots/rpi15_2020-01-08_17-24_cl/3, image ID: image_721
# Processing ArabidopsisDataset/Roots/rpi15_2020-01-08_17-24_cl/4, image ID: image_726
# Processing ArabidopsisDataset/Roots/rpi15_2020-03-12_17-01_ld/1, image ID: image_731
# Processing ArabidopsisDataset/Roots/rpi15_2020-03-12_17-01_ld/2, image ID: image_736
# Processing ArabidopsisDataset/Roots/rpi15_2020-03-12_17-01_ld/3, image ID: image_741
# Processing ArabidopsisDataset/Roots/rpi15_2020-03-12_17-01_ld/4, image ID: image_746
# Processing ArabidopsisDataset/Roots/rpi15_old/cam1, image ID: image_751
# Processing ArabidopsisDataset/Roots/rpi15_old/cam2, image ID: image_758
# Processing ArabidopsisDataset/Roots/rpi15_old/cam3, image ID: image_766
# Processing ArabidopsisDataset/Roots/rpi15_old/cam4, image ID: image_775
# Processing ArabidopsisDataset/Roots/rpi15_short_day_failed/1, image ID: image_784
# Processing ArabidopsisDataset/Roots/rpi15_short_day_failed/2, image ID: image_790
# Processing ArabidopsisDataset/Roots/rpi15_short_day_failed/3, image ID: image_796
# Processing ArabidopsisDataset/Roots/rpi15_short_day_failed/4, image ID: image_802
# Processing ArabidopsisDataset/Roots/test 1/1, image ID: image_808
# Processing ArabidopsisDataset/Roots/test 1/2, image ID: image_813
# Processing ArabidopsisDataset/Roots/test 1/3, image ID: image_818
# Processing ArabidopsisDataset/Roots/test 1/4, image ID: image_823
# Processing ArabidopsisDataset/Roots/test 2/1, image ID: image_828
# Processing ArabidopsisDataset/Roots/test 2/2, image ID: image_833
# Processing ArabidopsisDataset/Roots/test 2/3, image ID: image_838
# Processing ArabidopsisDataset/Roots/test 2/4, image ID: image_843
# Processing ArabidopsisDataset/Roots/test 3/2, image ID: image_848
# Processing ArabidopsisDataset/Roots/test 3/3, image ID: image_853
# Processing ArabidopsisDataset/Roots/test 3/4, image ID: image_858

# %%
import json
import numpy as np
import os

# Path to the folder_image_map.json file
folder_map_path = 'nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/folder_image_map.json'

# Path to save the splits file
splits_output_path = 'nnUNet_files/nnUNet_preprocessed/Dataset789_ChronoRoot2/splits_final.json'

# Make directories if they don't exist
os.makedirs(os.path.dirname(splits_output_path), exist_ok=True)

# Load the folder-to-images mapping
with open(folder_map_path, 'r') as f:
    folder_image_map = json.load(f)

# Get all folder IDs
folder_ids = list(folder_image_map.keys())

# Set a seed for reproducibility
np.random.seed(42)

# Shuffle the folder IDs
np.random.shuffle(folder_ids)

# Split the folder IDs into 5 folds
folder_folds = np.array_split(folder_ids, 5)

# Create the 5-fold cross validation splits
splits = []

for i in range(5):
    # Folders for validation in this fold
    val_folders = folder_folds[i]
    
    # Initialize train and validation lists
    train_images = []
    val_images = []
    
    # Assign images to train or validation based on their folder
    for folder_id in folder_ids:
        if folder_id in val_folders:
            # This folder goes to validation for this fold
            val_images.extend(folder_image_map[folder_id])
        else:
            # This folder goes to training for this fold
            train_images.extend(folder_image_map[folder_id])
    
    # Create the split dictionary
    split = {
        'train': train_images,
        'val': val_images
    }
    
    # Add to the splits list
    splits.append(split)

# Adds a fake folder 5 with all images in the training set for running inference later

# Initialize train and validation lists
train_images = []
val_images = []

# Assign images to train or validation based on their folder
for folder_id in folder_ids:
    val_images.extend(folder_image_map[folder_id])
    train_images.extend(folder_image_map[folder_id])

# Create the split dictionary
split = {
    'train': train_images,
    'val': val_images
}

# Add to the splits list
splits.append(split)

# Print some statistics
for i, split in enumerate(splits):
    print(f"Fold {i}: {len(split['train'])} training images, {len(split['val'])} validation images")

# Save the splits
os.makedirs(os.path.dirname(splits_output_path), exist_ok=True)
with open(splits_output_path, 'w') as f:
    json.dump(splits, f, indent=4)

print(f"\nSplits saved to: {splits_output_path}")
print(f"Total folders: {len(folder_ids)}")
print(f"Folders per fold: {[len(fold) for fold in folder_folds]}")
# Out:
# Fold 0: 671 training images, 126 validation images
# Fold 1: 656 training images, 141 validation images
# Fold 2: 636 training images, 161 validation images
# Fold 3: 639 training images, 158 validation images
# Fold 4: 586 training images, 211 validation images
# Fold 5: 797 training images, 797 validation images
#
# Splits saved to: nnUNet_files/nnUNet_preprocessed/Dataset789_ChronoRoot2/splits_final.json
# Total folders: 147
# Folders per fold: [30, 30, 29, 29, 29]
