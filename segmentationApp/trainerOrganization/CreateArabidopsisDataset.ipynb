# %%
import os
import shutil
import nibabel as nib
import cv2
import numpy as np
import pathlib
import re
import json
from collections import defaultdict
import random

def natural_sort_key(s, _nsre=re.compile('([0-9]+)')):
    return [int(text) if text.isdigit() else text.lower()
            for text in re.split(_nsre, s)]

# Input directories
path = "ArabidopsisDataset"
read_path = pathlib.Path(path).glob('*/*/*/*.png')
image_paths = sorted([str(path) for path in read_path], key=natural_sort_key)

# Output directories
outpath = "nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/imagesTr"
labels_outpath = "nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/labelsTr"

os.makedirs(outpath, exist_ok=True)
os.makedirs(labels_outpath, exist_ok=True)

# Group images by folder
folder_images = defaultdict(list)
for path in image_paths:
    # Get the folder path - using os.path for better compatibility
    folder_path = os.path.dirname(path)
    folder_images[folder_path].append(path)

# Create a mapping dictionary that includes the folder info
folder_image_map = defaultdict(list)

# Counter for image naming
counter = 1
image_id = ""

# Process all images grouped by folder
for folder, images in folder_images.items():
    folder_id = "Manual_Annotation_" + folder.replace("/", "_").replace(" ", "_")  # Create a safe folder ID
    
    print(f'Processing {folder}, image ID: {image_id}')
        
    # Process each image in the folder
    for path in images:
        # Create image ID
        image_id = f'image_{counter}'
        
        # Copy the image to the output directory
        shutil.copy(path, os.path.join(outpath, f'{image_id}_0000.png'))
        
        # Load the mask
        mask_path = path.replace('.png', '.nii.gz')
        mask = nib.load(mask_path).get_fdata().T
        
        if mask.shape[0] == 1:
            mask = mask[0]
        
        image = cv2.imread(path, 0)
        # Image shape and mask shape should be the same
        if image.shape[0] != mask.shape[0]:
            continue

        # Save the mask
        cv2.imwrite(os.path.join(labels_outpath, f'{image_id}.png'), mask.astype('uint8'))
        
        folder_image_map[folder_id].append(image_id)
        
        # Update the counter
        counter += 1

with open('nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/folder_image_map.json', '+w') as f:
    json.dump(folder_image_map, f, indent=4)
# Out:
# Processing ArabidopsisDataset/Etiolation/MultipleVids/Primeras listo, image ID:
# Processing ArabidopsisDataset/Etiolation/MultipleVids/Varios, image ID: image_4
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-07-29_14-47/1 listo, image ID: image_12
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-07-29_14-47/2 listo, image ID: image_16
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-07-29_14-47/3 listo, image ID: image_20
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-11-06_15-18/1, image ID: image_24
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-11-06_15-18/2, image ID: image_29
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-11-06_15-18/3, image ID: image_34
# Processing ArabidopsisDataset/Etiolation/rpi101_2024-11-06_15-18/4, image ID: image_39
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-06-11_14-10/1 listo, image ID: image_44
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-06-11_14-10/2 listo, image ID: image_48
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-06-11_14-10/3 listo, image ID: image_52
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-06-11_14-10/4 listo, image ID: image_56
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-07-29_14-54/1 listo, image ID: image_60
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-07-29_14-54/2 listo, image ID: image_64
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-07-29_14-54/3 listo, image ID: image_68
# Processing ArabidopsisDataset/Etiolation/rpi102_2024-07-29_14-54/4 listo, image ID: image_72
# Processing ArabidopsisDataset/Etiolation/rpi103_2024-11-06_15-23/1, image ID: image_76
# Processing ArabidopsisDataset/Etiolation/rpi103_2024-11-06_15-23/2, image ID: image_81
# Processing ArabidopsisDataset/Etiolation/rpi103_2024-11-06_15-23/3, image ID: image_86
# Processing ArabidopsisDataset/Etiolation/rpi103_2024-11-06_15-23/4, image ID: image_91
# Processing ArabidopsisDataset/Etiolation/rpi103_2025-06-27_15-00/1, image ID: image_96
# Processing ArabidopsisDataset/Etiolation/rpi103_2025-06-27_15-00/2, image ID: image_100
# Processing ArabidopsisDataset/Etiolation/rpi103_2025-06-27_15-00/3, image ID: image_104
# Processing ArabidopsisDataset/Etiolation/rpi103_2025-07-02_14-36/1, image ID: image_108
# Processing ArabidopsisDataset/Etiolation/rpi103_2025-07-02_14-36/2, image ID: image_112
# Processing ArabidopsisDataset/Etiolation/rpi103_2025-07-02_14-36/3, image ID: image_116
# Processing ArabidopsisDataset/Etiolation/rpi103_2025-07-02_14-36/4, image ID: image_120
# Processing ArabidopsisDataset/Germination/MultipleVids/AnnotatedSeeds, image ID: image_124
# Processing ArabidopsisDataset/Germination/MultipleVids/Varios, image ID: image_188
# Processing ArabidopsisDataset/Germination/rpi8_2024-07-02_14-41/1, image ID: image_210
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-02_14-40/1, image ID: image_212
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-02_14-40/2, image ID: image_214
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-02_14-40/3, image ID: image_216
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-02_14-40/4, image ID: image_218
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-08_15-50/1, image ID: image_220
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-08_15-50/2, image ID: image_222
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-08_15-50/3, image ID: image_224
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-08_15-50/4, image ID: image_226
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-16_10-09/1, image ID: image_228
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-16_10-09/2, image ID: image_230
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-16_10-09/3, image ID: image_231
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-16_10-09/4, image ID: image_232
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-22_13-29/1, image ID: image_233
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-22_13-29/2, image ID: image_234
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-22_13-29/3, image ID: image_235
# Processing ArabidopsisDataset/Germination/rpi12_2024-07-22_13-29/4, image ID: image_236
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-16_10-10/1, image ID: image_237
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-16_10-10/2, image ID: image_238
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-16_10-10/3, image ID: image_240
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-16_10-10/4, image ID: image_241
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-22_13-31/1, image ID: image_242
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-22_13-31/2, image ID: image_244
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-22_13-31/3, image ID: image_246
# Processing ArabidopsisDataset/Germination/rpi20_2024-07-22_13-31/4, image ID: image_249
# Processing ArabidopsisDataset/Germination/rpi101_2024-09-06_16-14/1, image ID: image_251
# Processing ArabidopsisDataset/Germination/rpi101_2024-09-06_16-14/2, image ID: image_256
# Processing ArabidopsisDataset/Germination/rpi101_2024-09-06_16-14/3, image ID: image_261
# Processing ArabidopsisDataset/Germination/rpi101_2024-09-06_16-14/4, image ID: image_266
# Processing ArabidopsisDataset/Germination/rpi101_2025-04-25_14-50/1, image ID: image_271
# Processing ArabidopsisDataset/Germination/rpi101_2025-04-25_14-50/2, image ID: image_275
# Processing ArabidopsisDataset/Germination/rpi101_2025-04-25_14-50/3, image ID: image_279
# Processing ArabidopsisDataset/Germination/rpi101_2025-04-25_14-50/4, image ID: image_283
# Processing ArabidopsisDataset/ManyRoots/rpi101_2024-11-25_14-48/1, image ID: image_287
# Processing ArabidopsisDataset/ManyRoots/rpi101_2024-11-25_14-48/2, image ID: image_294
# Processing ArabidopsisDataset/ManyRoots/rpi101_2024-11-25_14-48/3, image ID: image_301
# Processing ArabidopsisDataset/ManyRoots/rpi101_2024-11-25_14-48/4, image ID: image_308
# Processing ArabidopsisDataset/ManyRoots/rpi101_2025-04-16_17-10/1, image ID: image_315
# Processing ArabidopsisDataset/ManyRoots/rpi101_2025-04-16_17-10/2, image ID: image_321
# Processing ArabidopsisDataset/ManyRoots/rpi101_2025-04-16_17-10/3, image ID: image_327
# Processing ArabidopsisDataset/ManyRoots/rpi101_2025-04-16_17-10/4, image ID: image_333
# Processing ArabidopsisDataset/ManyRoots/rpi103_2024-11-25_14-49/1, image ID: image_339
# Processing ArabidopsisDataset/ManyRoots/rpi103_2024-11-25_14-49/2, image ID: image_346
# Processing ArabidopsisDataset/ManyRoots/rpi103_2024-11-25_14-49/3, image ID: image_353
# Processing ArabidopsisDataset/ManyRoots/rpi103_2024-11-25_14-49/4, image ID: image_360
# Processing ArabidopsisDataset/ManyRoots/rpi103_2025-04-16_17-11/1, image ID: image_367
# Processing ArabidopsisDataset/ManyRoots/rpi103_2025-04-16_17-11/2, image ID: image_373
# Processing ArabidopsisDataset/ManyRoots/rpi103_2025-04-16_17-11/3, image ID: image_379
# Processing ArabidopsisDataset/ManyRoots/rpi103_2025-04-16_17-11/4, image ID: image_385
# Processing ArabidopsisDataset/Roots/MultipleVids/rotas, image ID: image_391
# Processing ArabidopsisDataset/Roots/MultipleVids/rpi15_4, image ID: image_404
# Processing ArabidopsisDataset/Roots/rpi4_old/cam2, image ID: image_407
# Processing ArabidopsisDataset/Roots/rpi5_old/cam1, image ID: image_415
# Processing ArabidopsisDataset/Roots/rpi6/1, image ID: image_422
# Processing ArabidopsisDataset/Roots/rpi6/2, image ID: image_426
# Processing ArabidopsisDataset/Roots/rpi6/3, image ID: image_431
# Processing ArabidopsisDataset/Roots/rpi6/4, image ID: image_436
# Processing ArabidopsisDataset/Roots/rpi6_2019-12-09_16-12/1, image ID: image_441
# Processing ArabidopsisDataset/Roots/rpi6_2019-12-09_16-12/2, image ID: image_446
# Processing ArabidopsisDataset/Roots/rpi6_2019-12-09_16-12/3, image ID: image_451
# Processing ArabidopsisDataset/Roots/rpi6_2019-12-09_16-12/4, image ID: image_456
# Processing ArabidopsisDataset/Roots/rpi6_2020-01-08_17-25_cl/1, image ID: image_461
# Processing ArabidopsisDataset/Roots/rpi6_2020-01-08_17-25_cl/2, image ID: image_466
# Processing ArabidopsisDataset/Roots/rpi6_2020-01-08_17-25_cl/3, image ID: image_471
# Processing ArabidopsisDataset/Roots/rpi6_2020-01-08_17-25_cl/4, image ID: image_476
# Processing ArabidopsisDataset/Roots/rpi6_2020-03-12_17-01_ld/2, image ID: image_481
# Processing ArabidopsisDataset/Roots/rpi6_2020-03-12_17-01_ld/3, image ID: image_486
# Processing ArabidopsisDataset/Roots/rpi6_2020-03-12_17-01_ld/4, image ID: image_491
# Processing ArabidopsisDataset/Roots/rpi6_old/cam1, image ID: image_496
# Processing ArabidopsisDataset/Roots/rpi6_old/cam2, image ID: image_502
# Processing ArabidopsisDataset/Roots/rpi6_old/cam3, image ID: image_509
# Processing ArabidopsisDataset/Roots/rpi6_old/cam4, image ID: image_516
# Processing ArabidopsisDataset/Roots/rpi6_short_day_col0_ler/1, image ID: image_522
# Processing ArabidopsisDataset/Roots/rpi6_short_day_col0_ler/2, image ID: image_528
# Processing ArabidopsisDataset/Roots/rpi6_short_day_col0_ler/4, image ID: image_534
# Processing ArabidopsisDataset/Roots/rpi6_short_day_failed/1, image ID: image_540
# Processing ArabidopsisDataset/Roots/rpi6_short_day_failed/2, image ID: image_546
# Processing ArabidopsisDataset/Roots/rpi6_short_day_failed/3, image ID: image_552
# Processing ArabidopsisDataset/Roots/rpi6_short_day_failed/4, image ID: image_558
# Processing ArabidopsisDataset/Roots/rpi8_short_day_col0_ler/1, image ID: image_564
# Processing ArabidopsisDataset/Roots/rpi8_short_day_col0_ler/2, image ID: image_570
# Processing ArabidopsisDataset/Roots/rpi8_short_day_col0_ler/3, image ID: image_576
# Processing ArabidopsisDataset/Roots/rpi8_short_day_col0_ler/4, image ID: image_582
# Processing ArabidopsisDataset/Roots/rpi9_short_day_col0_ler/1, image ID: image_588
# Processing ArabidopsisDataset/Roots/rpi9_short_day_col0_ler/2, image ID: image_594
# Processing ArabidopsisDataset/Roots/rpi9_short_day_col0_ler/4, image ID: image_600
# Processing ArabidopsisDataset/Roots/rpi13_old/cam1, image ID: image_606
# Processing ArabidopsisDataset/Roots/rpi13_old/cam2, image ID: image_614
# Processing ArabidopsisDataset/Roots/rpi13_old/cam3, image ID: image_622
# Processing ArabidopsisDataset/Roots/rpi13_old/cam4, image ID: image_630
# Processing ArabidopsisDataset/Roots/rpi14_2019-12-09_16-13/1, image ID: image_637
# Processing ArabidopsisDataset/Roots/rpi14_2019-12-09_16-13/2, image ID: image_642
# Processing ArabidopsisDataset/Roots/rpi14_2019-12-09_16-13/3, image ID: image_647
# Processing ArabidopsisDataset/Roots/rpi14_2019-12-09_16-13/4, image ID: image_652
# Processing ArabidopsisDataset/Roots/rpi14_2020-01-08_17-25_cl/1, image ID: image_657
# Processing ArabidopsisDataset/Roots/rpi14_2020-01-08_17-25_cl/3, image ID: image_662
# Processing ArabidopsisDataset/Roots/rpi14_2020-01-08_17-25_cl/4, image ID: image_667
# Processing ArabidopsisDataset/Roots/rpi14_2020-03-12_17-00_ld/1, image ID: image_671
# Processing ArabidopsisDataset/Roots/rpi14_2020-03-12_17-00_ld/2, image ID: image_676
# Processing ArabidopsisDataset/Roots/rpi14_2020-03-12_17-00_ld/3, image ID: image_681
# Processing ArabidopsisDataset/Roots/rpi14_2020-03-12_17-00_ld/4, image ID: image_686
# Processing ArabidopsisDataset/Roots/rpi14_old/cam1, image ID: image_691
# Processing ArabidopsisDataset/Roots/rpi14_old/cam2, image ID: image_700
# Processing ArabidopsisDataset/Roots/rpi14_old/cam3, image ID: image_708
# Processing ArabidopsisDataset/Roots/rpi14_old/cam4, image ID: image_716
# Processing ArabidopsisDataset/Roots/rpi14_short_day_failed/1, image ID: image_725
# Processing ArabidopsisDataset/Roots/rpi14_short_day_failed/2, image ID: image_731
# Processing ArabidopsisDataset/Roots/rpi14_short_day_failed/3, image ID: image_737
# Processing ArabidopsisDataset/Roots/rpi14_short_day_failed/4, image ID: image_743
# Processing ArabidopsisDataset/Roots/rpi15_2019-12-09_16-14/1, image ID: image_749
# Processing ArabidopsisDataset/Roots/rpi15_2019-12-09_16-14/2, image ID: image_754
# Processing ArabidopsisDataset/Roots/rpi15_2019-12-09_16-14/3, image ID: image_759
# Processing ArabidopsisDataset/Roots/rpi15_2020-01-08_17-24_cl/1, image ID: image_764
# Processing ArabidopsisDataset/Roots/rpi15_2020-01-08_17-24_cl/3, image ID: image_769
# Processing ArabidopsisDataset/Roots/rpi15_2020-01-08_17-24_cl/4, image ID: image_774
# Processing ArabidopsisDataset/Roots/rpi15_2020-03-12_17-01_ld/1, image ID: image_779
# Processing ArabidopsisDataset/Roots/rpi15_2020-03-12_17-01_ld/2, image ID: image_784
# Processing ArabidopsisDataset/Roots/rpi15_2020-03-12_17-01_ld/3, image ID: image_789
# Processing ArabidopsisDataset/Roots/rpi15_2020-03-12_17-01_ld/4, image ID: image_794
# Processing ArabidopsisDataset/Roots/rpi15_old/cam1, image ID: image_799
# Processing ArabidopsisDataset/Roots/rpi15_old/cam2, image ID: image_806
# Processing ArabidopsisDataset/Roots/rpi15_old/cam3, image ID: image_814
# Processing ArabidopsisDataset/Roots/rpi15_old/cam4, image ID: image_823
# Processing ArabidopsisDataset/Roots/rpi15_short_day_failed/1, image ID: image_832
# Processing ArabidopsisDataset/Roots/rpi15_short_day_failed/2, image ID: image_838
# Processing ArabidopsisDataset/Roots/rpi15_short_day_failed/3, image ID: image_844
# Processing ArabidopsisDataset/Roots/rpi15_short_day_failed/4, image ID: image_850
# Processing ArabidopsisDataset/Roots/test 1/1, image ID: image_856
# Processing ArabidopsisDataset/Roots/test 1/2, image ID: image_861
# Processing ArabidopsisDataset/Roots/test 1/3, image ID: image_866
# Processing ArabidopsisDataset/Roots/test 1/4, image ID: image_871
# Processing ArabidopsisDataset/Roots/test 2/1, image ID: image_876
# Processing ArabidopsisDataset/Roots/test 2/2, image ID: image_881
# Processing ArabidopsisDataset/Roots/test 2/3, image ID: image_886
# Processing ArabidopsisDataset/Roots/test 2/4, image ID: image_891
# Processing ArabidopsisDataset/Roots/test 3/2, image ID: image_896
# Processing ArabidopsisDataset/Roots/test 3/3, image ID: image_901
# Processing ArabidopsisDataset/Roots/test 3/4, image ID: image_906

# %%
import json
import numpy as np
import os
import random

# Path to the folder_image_map.json file
folder_map_path = 'nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/folder_image_map.json'

# Path to save the splits file
splits_output_path = 'nnUNet_files/nnUNet_preprocessed/Dataset789_ChronoRoot2/splits_final.json'

# Make directories if they don't exist
os.makedirs(os.path.dirname(splits_output_path), exist_ok=True)

# Load the folder-to-images mapping
with open(folder_map_path, 'r') as f:
    folder_image_map = json.load(f)

# Set a seed for reproducibility
random.seed(42)
np.random.seed(42)

# Group folders by major category
major_categories = {}
for folder_id in folder_image_map.keys():
    # Extract major category from folder name
    # Format: Manual_Annotation_ArabidopsisDataset_<CATEGORY>_...
    parts = folder_id.split('_')
    if len(parts) >= 4:
        category = parts[3]  # Etiolation, Germination, ManyRoots, or Roots
        if category not in major_categories:
            major_categories[category] = []
        major_categories[category].append(folder_id)

print("Major categories found:")
for cat, folders in major_categories.items():
    print(f"  {cat}: {len(folders)} folders")

# Initialize train, val, test lists
train_folders = []
val_folders = []
test_folders = []

# Process each major category
for category, folders in major_categories.items():
    print(f"\nProcessing category: {category}")
    
    # Separate MultipleVids folders (always go to train)
    multiplevids_folders = [f for f in folders if "MultipleVids" in f]
    other_folders = [f for f in folders if "MultipleVids" not in f]
    
    print(f"  MultipleVids folders: {len(multiplevids_folders)} (→ train)")
    print(f"  Other folders: {len(other_folders)}")
    
    # Add MultipleVids folders to train
    train_folders.extend(multiplevids_folders)
    
    # Shuffle other folders
    random.shuffle(other_folders)
    
    # Calculate split sizes (70-10-20)
    n_other = len(other_folders)
    n_train = int(0.7 * n_other)
    n_val = int(0.1 * n_other)
    # n_test is the remainder
    
    # Split the other folders
    train_other = other_folders[:n_train]
    val_other = other_folders[n_train:n_train + n_val]
    test_other = other_folders[n_train + n_val:]
    
    print(f"  Split: {len(train_other)} train, {len(val_other)} val, {len(test_other)} test")
    
    # Add to respective lists
    train_folders.extend(train_other)
    val_folders.extend(val_other)
    test_folders.extend(test_other)

# Convert folder lists to image lists
train_images = []
val_images = []
test_images = []

for folder in train_folders:
    train_images.extend(folder_image_map[folder])

for folder in val_folders:
    val_images.extend(folder_image_map[folder])

for folder in test_folders:
    test_images.extend(folder_image_map[folder])

# Create the split dictionary (single split with train/val/test)
splits = [{
    'train': train_images,
    'val': val_images,
    'test': test_images
}]

# Print statistics
print(f"\n{'='*60}")
print(f"FINAL SPLIT STATISTICS")
print(f"{'='*60}")
print(f"Total folders: {len(folder_image_map)}")
print(f"  Train folders: {len(train_folders)}")
print(f"  Val folders: {len(val_folders)}")
print(f"  Test folders: {len(test_folders)}")
print(f"\nTotal images: {len(train_images) + len(val_images) + len(test_images)}")
print(f"  Train images: {len(train_images)} ({100*len(train_images)/(len(train_images)+len(val_images)+len(test_images)):.1f}%)")
print(f"  Val images: {len(val_images)} ({100*len(val_images)/(len(train_images)+len(val_images)+len(test_images)):.1f}%)")
print(f"  Test images: {len(test_images)} ({100*len(test_images)/(len(train_images)+len(val_images)+len(test_images)):.1f}%)")

# Save the splits
with open(splits_output_path, 'w') as f:
    json.dump(splits, f, indent=4)

print(f"\nSplits saved to: {splits_output_path}")

# Also save folder assignments for transparency
folder_assignments = {
    'train_folders': train_folders,
    'val_folders': val_folders,
    'test_folders': test_folders
}

folder_assignments_path = splits_output_path.replace('splits_final.json', 'folder_assignments.json')
with open(folder_assignments_path, 'w') as f:
    json.dump(folder_assignments, f, indent=4)

print(f"Folder assignments saved to: {folder_assignments_path}")
# Out:
# Major categories found:
#   Etiolation: 28 folders
#   Germination: 35 folders
#   ManyRoots: 16 folders
#   Roots: 89 folders
#
# Processing category: Etiolation
#   MultipleVids folders: 2 (→ train)
#   Other folders: 26
#   Split: 18 train, 2 val, 6 test
#
# Processing category: Germination
#   MultipleVids folders: 2 (→ train)
#   Other folders: 33
#   Split: 23 train, 3 val, 7 test
#
# Processing category: ManyRoots
#   MultipleVids folders: 0 (→ train)
#   Other folders: 16
#   Split: 11 train, 1 val, 4 test
#
# Processing category: Roots
#   MultipleVids folders: 2 (→ train)
#   Other folders: 87
#   Split: 60 train, 8 val, 19 test
#
# ============================================================
# FINAL SPLIT STATISTICS
# ============================================================
# Total folders: 168
#   Train folders: 118
#   Val folders: 14
#   Test folders: 36
#
# Total images: 911
#   Train images: 667 (73.2%)
#   Val images: 68 (7.5%)
#   Test images: 176 (19.3%)
#
# Splits saved to: nnUNet_files/nnUNet_preprocessed/Dataset789_ChronoRoot2/splits_final.json
# Folder assignments saved to: nnUNet_files/nnUNet_preprocessed/Dataset789_ChronoRoot2/folder_assignments.json

# %%
import json
import shutil
import os

# Paths
splits_path = 'nnUNet_files/nnUNet_preprocessed/Dataset789_ChronoRoot2/splits_final.json'
images_tr_path = 'nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/imagesTr'
labels_tr_path = 'nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/labelsTr'

images_ts_path = 'nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/imagesTs'
labels_ts_path = 'nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/labelsTs'

# Create output directories
os.makedirs(images_ts_path, exist_ok=True)
os.makedirs(labels_ts_path, exist_ok=True)

# Load the splits
with open(splits_path, 'r') as f:
    splits = json.load(f)

# Get test images (assuming first split contains train/val/test)
test_images = splits[0]['test']

print(f"Copying {len(test_images)} test images...")

# Copy each test image and its label
for image_id in test_images:
    # Copy image
    src_image = os.path.join(images_tr_path, f'{image_id}_0000.png')
    dst_image = os.path.join(images_ts_path, f'{image_id}_0000.png')
    
    if os.path.exists(src_image):
        shutil.copy(src_image, dst_image)
    else:
        print(f"Warning: Image not found: {src_image}")
    
    # Copy label
    src_label = os.path.join(labels_tr_path, f'{image_id}.png')
    dst_label = os.path.join(labels_ts_path, f'{image_id}.png')
    
    if os.path.exists(src_label):
        shutil.copy(src_label, dst_label)
    else:
        print(f"Warning: Label not found: {src_label}")

print(f"\nDone!")
print(f"Images copied to: {images_ts_path}")
print(f"Labels copied to: {labels_ts_path}")
# Out:
# Copying 176 test images...
#
# Done!
# Images copied to: nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/imagesTs
# Labels copied to: nnUNet_files/nnUNet_raw/Dataset789_ChronoRoot2/labelsTs
